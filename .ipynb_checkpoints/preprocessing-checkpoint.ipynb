# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_with_labels = pd.read_csv("Audiobooks_data_with_labels.csv")
df = pd.read_csv("Audiobooks_data.csv")
df_with_labels
# Out:
#           ID  Book length(mins)_overall  Book length(mins)_avg  Price_overall  \
# 0        994                     1620.0                   1620          19.73
# 1       1143                     2160.0                   2160           5.33
# 2       2059                     2160.0                   2160           5.33
# 3       2882                     1620.0                   1620           5.96
# 4       3342                     2160.0                   2160           5.33
# ...      ...                        ...                    ...            ...
# 14079  28220                     1620.0                   1620           5.33
# 14080  28671                     1080.0                   1080           6.55
# 14081  31134                     2160.0                   2160           6.14
# 14082  32832                     1620.0                   1620           5.33
# 14083    251                     1674.0                   3348           5.33
#
# ...

# %% [raw]
# Explaining each column
# Book length(mins)_overall = sum of length of all books purchased
# Book length(mins)_avg = sum of the length of all books purchased/ number of books purchased
#
# Price_overall = total price on book purchased
# Price_avg	 = Price_overall / number of books purchased
# Review = if a customer review or not
# Review 10/10 = reviews in range of 1-10 to show satisfactory, average is provided for user without reviews
# Completion = len of book in minutes / minutes read
# Support Requests = amount of support request
# Last visit - Purchased date = when user visited last since puchase date
# Targets= result of each user after 6 month , 0- not converted , 1 - converted

# %% [markdown]
# ## Lets get our inpendents and dependent variables.

# %%
data = df_with_labels.copy()
print(data.columns.values)
y = data["Targets"]
# In my opinion these xs are better
x = data[[
    "Completion",
    "Review",
    "Review 10/10",
    "Last visit - Purchased date",
    "Support Requests",
    "Book length(mins)_overall",
    "Price_avg"
]]
# Out:
# ['ID' 'Book length(mins)_overall' 'Book length(mins)_avg' 'Price_overall'
#  'Price_avg' 'Review' 'Review 10/10' 'Minutes listened' 'Completion'
#  'Support Requests' 'Last visit - Purchased date' 'Targets']
# C:\Users\USER\anaconda3\envs\tf2\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## Test for linearity

# %%
for column in x.columns:
    plt.figure(figsize=(6, 4))
    
    # if x[column].nunique() <= 2:  # Binary feature
    #     # Bar plot of average y for each value of the binary feature
    #     means = y.groupby(x[column]).mean()
    #     plt.bar(means.index.astype(str), means.values)
    #     plt.ylabel("Average Target (Conversion Rate)")
    #     plt.xlabel(column)
    #     plt.title(f"Conversion Rate by {column}")
    # else:
    # Scatter plot
    plt.scatter(x[column], y, alpha=0.5)
    plt.xlabel(column)
    plt.ylabel("Target (0 = Not Converted, 1 = Converted)")
    plt.title(f"{column} vs Target")
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Lets solve using SKLEARN,  Logit SHOULD WORKS FINE

# %% [raw]
# This is  not a linear problem so logit should work and it gives our input a probability that we can then clasify to a zero or 1

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 from sklearn.linear_model import LogisticRegression
#       3 model = LogisticRegression()
#
# ModuleNotFoundError: No module named 'sklearn'
